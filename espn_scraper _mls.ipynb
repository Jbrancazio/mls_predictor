# %% [markdown]
# # Collecting Data from ESPN

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# I am going to start working with one team in the MLS, LAFC. This will allow me to start gathering the information for this team only and then I can expand from here. My process for this scraper is to
#
# 1. Create a list of all game id's for LAFC over the course of their history
# 2. Use these game ID's to pull game data from the ESPN website
# 3. Remove any games that have happened in the 2020 season so far
# 4. Expand this data collection to be able to include all teams in the MLS
# 5. Use this data to create a model to predict the results of the 2020 MLS season (if it ever actually happens)

# %% [markdown]
# ### 1. List of game id's for LAFC

# %% [markdown]
# #### 1.a First attempt to pull game Id's

# %%
#create a page and us beautiful soup to parse out the content
lafc_page=requests.get("https://global.espn.com/soccer/team/_/id/18966/lafc")
lafc_page

lafc_soup= BeautifulSoup(lafc_page.content, "html.parser")
lafc_soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-icon-fonts" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <link href="https://global.espn.com/football/team/_/id/18966/lafc" rel="canonical"/>
# <title>LAFC  News and Scores - ESPN</title>
# <meta content="Get the latest LAFC news, scores, stats, standings, rumors, and more from ESPN." name="description">
# <meta content="lafc, soccer, soccer, scores, news, schedule, highlights" name="news_keywords">
# <meta content="lafc, soccer, soccer, scores, news, schedule, highlights" name="keywords"/>
# <meta content="116656161708917" property="fb:app_id"/>
# <meta content="ESPN.com" property="og:site_name"/>
# <meta content="https://global.espn.com/football/team/_/id/18966/lafc" property="og:url"/>
# <meta content="LAFC  News and Scores - ESPN" property="og:title"/>
# <meta content="Get the latest LAFC news, scores, stats, standings, rumors, and more from ESPN." property="og:description"/>
# <meta content="https://a.espncdn.com/combiner/i?img=%2Fi%2Fteamlogos%2Fsoccer%2F500%2F18966.png" property="og:image"/>
# <meta content="500" property="og:image:width"/>
# <meta content="500" property="og:image:height"/>
# <meta content="article" property="og:type"/>
# <meta content="false" property="article:opinion"/>
# <meta content="free" property="article:content_tier"/>
# <meta content="104266592953439" property="fb:pages"/>
# <meta content="espn" name="twitter:site"/>
# <meta content="https://global.espn.com/football/team/_/id/18966/lafc" name="twitter:url"/>
# <meta content="LAFC  News and Scores - ESPN" name="twitter:title"/>
# <meta content="Get the latest LAFC news, scores, stats, standings, rumors, and more from ESPN." name="twitter:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="ESPN" name="twitter:app:name:iphone">
# <meta content="317469184" name="twitter:app:id:iphone"/>
# <meta content="ESPN" name="twitter:app:name:googleplay"/>
# <meta content="com.espn.score_center" name="twitter:app:id:googleplay"/>
# <meta content="LAFC  News and Scores - ESPN" name="title"/>
# <meta content="article" name="medium"/>
# <!-- Indicate preferred brand name for Google to display -->
# <script type="application/ld+json">
# 	{
# 		"@context": "https://schema.org",
# 		"@type":    "WebSite",
# 		"name":     "null",
# 		"url":      "https://global.espn.com/"
# 	}
# </script>
# <!--
# <PageMap>
# 	<DataObject type="document">
# 		<Attribute name="title">LAFC  News and Scores</Attribute>
# 	</DataObject>
# 	<DataObject type="thumbnail">
# 		<Attribute name="src" value="https://a.espncdn.com/combiner/i?img=%2Fi%2Fteamlogos%2Fsoccer%2F500%2F18966.png" />
# 		<Attribute name="width" value="500" />
# 		<Attribute name="height" value="500" />
# 	</DataObject>
# </PageMap>
# -->
# <script src="https://nexus.ensighten.com/TWDC-DTCI/prod/Bootstrap.js" type="text/javascript"></script>
# <link href="https://www.espn.com/soccer/team/_/id/18966/lafc" hreflang="en-us" rel="alternate"/>
# <link href="https://www.espn.com.br/futebol/time/_/id/18966/lafc" hreflang="pt" rel="alternate"/>
# <link href="https://www.espn.in/football/team/_/id/18966/lafc" hreflang="en-in" rel="alternate"/>
# <link href="https://africa.espn.com/football/team/_/id/18966/lafc" hreflang="en-za" rel="alternate"/>
# <link href="https://espn.com.do/futbol/equipo/_/id/18966/lafc" hreflang="es-do" rel="alternate"/>
# <link href="https://www.espn.com.au/football/team/_/id/18966/lafc" hreflang="en-au" rel="alternate"/>
# <link href="https://www.espn.com.ec/futbol/equipo/_/id/18966/lafc" hreflang="es-ec" rel="alternate"/>
# <link href="https://espndeportes.espn.com/futbol/equipo/_/id/18966/lafc" hreflang="es-us" rel="alternate"/>
# <link href="https://tv5.espn.com/football/team/_/id/18966/lafc" hreflang="en-ph" rel="alternate"/>
# <link href="https://www.espn.com.br/futebol/time/_/id/18966/lafc" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.espn.com.uy/futbol/equipo/_/id/18966/lafc" hreflang="es-uy" rel="alternate"/>
# <link href="https://www.espn.com.gt/futbol/equipo/_/id/18966/lafc" hreflang="es-gt" rel="alternate"/>
# <link href="https://www.espn.com/soccer/team/_/id/18966/lafc" hreflang="en" rel="alternate"/>
# <link href="https://espndeportes.espn.com/futbol/equipo/_/id/18966/lafc" hreflang="es-es" rel="alternate"/>
# <link href="https://www.espn.com.ve/futbol/equipo/_/id/18966/lafc" hreflang="es-ve" rel="alternate"/>
# <link href="https://www.espn.co.cr/futbol/equipo/_/id/18966/lafc" hreflang="es-cr" rel="alternate"/>
# <link href="https://www.espn.cl/futbol/equipo/_/id/18966/lafc" hreflang="es-cl" rel="alternate"/>
# <link href="https://www.espn.com.mx/futbol/equipo/_/id/18966/lafc" hreflang="es-mx" rel="alternate"/>
# <link href="https://espndeportes.espn.com/futbol/equipo/_/id/18966/lafc" hreflang="es" rel="alternate"/>
# <link href="https://www.espn.com.co/futbol/equipo/_/id/18966/lafc" hreflang="es-co" rel="alternate"/>
# <link href="https://www.espn.com.pe/futbol/equipo/_/id/18966/lafc" hreflang="es-pe" rel="alternate"/>
# <link href="https://www.espn.com.ar/futbol/equipo/_/id/18966/lafc" hreflang="es-ar" rel="alternate"/>
# <link href="https://www.espn.com.pa/futbol/equipo/_/id/18966/lafc" hreflang="es-pa" rel="alternate"/>
# <link href="https://www.espn.com.sg/soccer/team/_/id/18966/lafc" hreflang="en-sg" rel="alternate"/>
# <link href="https://www.espn.co.uk/football/team/_/id/18966/lafc" hreflang="en-gb" rel="alternate"/>
# <script type="text/javascript">
# ;(function(){
#
# function rc(a){for(var b=a+"=",c=document.cookie.split(";"),d=0;d<c.length;d++){for(var e=c[d];" "===e.charAt(0);)e=e.substring(1,e.length);if(0===e.indexOf(b))return e.substring(b.length,e.length)}return null}var _nr=!1,_nrCookie=rc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):Math.floor(100*Math.random())+1===13?(_nr=!0,document.cookie="_nr=1; path=/"):(_nr=!1,document.cookie="_nr=0; path=/");_nr&&(function(){window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e) ...
#
# })();
# </script><script src="https://secure.espn.com/core/format/modules/head/i18n?edition-host=global.espn.com&amp;lang=en®ion=ww&amp;site=espn&amp;site-type=full&amp;type=ext&amp;build=0.486.8.2"></script>
# <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://tredir.go.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
# <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://secure.espn.com" rel="preconnect"/>
# <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
# <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon">
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon">
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="https://a.espncdn.com/redesign/fonts/base64-benton-woff.css" id="font-link" rel="stylesheet"/><link href="https://a.espncdn.com/redesign/0.486.8/css/shell-desktop.css" rel="stylesheet"><link href="https://a.espncdn.com/redesign/0.486.8/css/page.css" rel="stylesheet"/><link class="page-type-include" href="https://a.espncdn.com/redesign/0.486.8/css/clubhouses.css" rel="stylesheet"/>
# <script src="https://a.espncdn.com/redesign/0.486.8/js/espn-head.js"></script>
# <script>
# 			if (espn && espn.geoRedirect){
# 				espn.geoRedirect.run();
# 			}
# 		</script>
# <script>
# 	var espn = espn || {};
# 	espn.isOneSite = false;
# 	espn.build = "0.486.8";
# 	espn.siteType = "full";
# 	espn.anonymous_favorites = "true" === "true";
# 	espn.isFantasycast = false;
#
# 	espn.absoluteNavLinks = false;
# 	espn.useBranch = false;
# 	espn.useEPlus = true;
# 	espn.enableObscuredAdsSkipping = false;
#
# 	espn.enableInlinePlayback = true
# 	espn.enableInlinePPV = true
# </script>
# <script async="" src="https://a.espncdn.com/redesign/0.486.8/node_modules/espn-lazysizes/lazysizes.js"></script>
# <script type="text/javascript">
# 	(function () {
# 		var featureGating;
#
# 		try {
# 			featureGating = JSON.parse('{"playerFollowing":true,"gateFavorites":true,"browerDeprecation":true,"siteBroadcast":true}');
# 		} catch (e) {}
#
# 		window.espn.featureGating = featureGating || {};
# 	})();
# </script>
# <script>
# 		window.googletag = window.googletag || {};
#
# 		(function () {
# 			espn = window.espn || {};
# 			espn.ads = espn.ads || {};
# 			espn.ads.config = {"page_url":"https://global.espn.com/football/team/_/id/18966/lafc","prebidAdConfig":{"usePrebidBids":true,"timeout":1000},"level":"espn.global/soccer/team","delayInPageAdSlots":true,"incontentPositions":{"defaults":{"favorites":4,"news":4,"now":4},"index":{"top":{},"nfl":{}}},"showEspnPlusAds":false,"network":"21783347309","refreshOnBreakpointChange":true,"sizes":{"overlay":{"mappings":[{"viewport":[0,0],"slot":[[1,1]]}],"defaultSize":[1,1]},"wallpaper":{"mappings":[{"viewport":[1280,0],"slot":[[1680,1050]]},{"viewport":[1024,0],"slot":[[1280,455]]},{"viewport":[0,0],"slot":[]}],"defaultSize":[1280,455]},"incontent2":{"mappings":[{"viewport":[0,0],"slot":[[300,250]]}],"defaultSize":[300,250]},"banner":{"mappings":[{"viewport":[1280,0],"slot":[[1280,100],[970,250]]},{"viewport":[1024,0],"slot":[[970,66],[970,250]]},{"viewport":[768,0],"slot":[[728,90]]},{"viewport":[0,0],"slot":[320,50]}],"defaultSize":[970,250],"pbjs":{"s":[[320,50]],"xl":[[970,250]],"l":[[970,250],[728,90]],"m":[[728,90]]}},"exclusions":{"mappings":[{"viewport":[0,0],"slot":[[1,2]]}],"defaultSize":[1,2]},"presby":{"mappings":[{"viewport":[0,0],"slot":[[112,62]]}],"defaultSize":[112,62]},"native":{"mappings":[{"viewport":[0,0],"slot":["fluid"]}],"defaultSize":"fluid"},"incontentstrip":{"mappings":[{"viewport":[0,0],"slot":[298,50]}],"defaultSize":[298,50]},"instream":{"mappings":[{"viewport":[0,0],"slot":[[1,3]]}],"defaultSize":[1,3]},"incontentstrip2":{"mappings":[{"viewport":[320,0],"slot":[[298,50]]}],"defaultSize":[298,50]},"clubhouse":{"mappings":[{"viewport":[1024,0],"slot":[[300,100]]},{"viewport":[0,0],"slot":[]}],"defaultSize":[300,100]},"incontent":{"mappings":[{"viewport":[1024,0],"slot":[[300,250],[300,600]]},{"viewport":[768,0],"slot":[]},{"viewport":[0,0],"slot":[300,250]}],"defaultSize":[300,250]},"midpage":{"mappings":[{"viewport":[1280,0],"slot":[[700,400]]},{"viewport":[1024,0],"slot":[[440,330]]},{"viewport":[768,0],"slot":[[320,250]]},{"viewport":[0,0],"slot":[[320,250]]}],"defaultSize":[320,250]}},"load":{"schedule":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"frontpage":{"tablet":"init","desktop":"init","mobile":"window.load"},"defaults":{"tablet":"init","desktop":"init","mobile":"window.load"},"index":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"scoreboard":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"standings":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"},"story":{"tablet":"window.load","desktop":"window.load","mobile":"window.load"}},"refreshRate":120,"supportDynamicPageLoad":true,"selector":".ad-slot","disabled":"false","breakpoints":{"s":[0,767],"xl":[1280],"l":[1024,1279],"m":[768,1023]},"dynamicKeyValues":{"profile":{"key":"prof"}},"id":12129255,"kvps":[{"name":"ed","value":"global"},{"name":"sp","value":"soccer"},{"name":"tm","value":"lafc"},{"name":"pgtyp","value":"clubhouse"},{"name":"darkmode","value":"false"}],"base":"espn.global"};
# 			googletag.cmd = googletag.cmd || [];
#
# 			var espnAdsConfig = espn.ads.config;
#
# 			espn.ads.loadGPT = function () {
# 				var gads = document.createElement('script');
# 				gads.async = true;
# 				gads.type = 'text/javascript';
# 				gads.src = 'https://www.googletagservices.com/tag/js/gpt.js';
# 				var node = document.getElementsByTagName('script')[0];
# 				node.parentNode.insertBefore(gads, node);
# 				delete espn.ads.loadGPT;
# 			}
#
# 			if (espn.siteType === 'data-lite') {
# 				/**
# 				 * Load ad library after our deferred files. Event subscription must
# 				 * occur on window.load to ensure pub/sub availability.
# 				 */
#
# 				// Ad calls will be made when ad library inits (after window.load).
# 				var liteAdLoadConfigs = {
# 					desktop: 'init',
# 					mobile: 'init',
# 					tablet: 'init'
# 				};
#
# 				espnAdsConfig.load = espnAdsConfig.load || {};
# 				espnAdsConfig.load.defaults = liteAdLoadConfigs
# 				espnAdsConfig.load.frontpage = liteAdLoadConfigs;
# 				espnAdsConfig.load.index = liteAdLoadConfigs;
# 				espnAdsConfig.load.story = liteAdLoadConfigs;
# 			} else {
# 				espn.ads.loadGPT();
# 			}
#
# 			if (espnAdsConfig.prebidAdConfig && espnAdsConfig.prebidAdConfig.usePrebidBids) {
#
#
# 				// Load prebid.js for AppNexus
# 				(function() {
# 					var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
# 					pbs.type = 'text/javascript';
# 					pbs.src = ((pro === 'https:') ? 'https' : 'http') + '://a.espncdn.com/prod/scripts/prebid2.25.0.js';
# 					var target = document.getElementsByTagName('head')[0];
# 					target.insertBefore(pbs, target.firstChild);
# 				})();
# 			}
#
# 			espn.ads.configPre = JSON.parse(JSON.stringify(espnAdsConfig));
# 		})();
# 	</script>
# <script type="text/javascript">
# 	if( typeof s_omni === "undefined" ) window.s_account = window.setReportSuite( "wdgespcom" );
# </script>
# <script>
# 	// Picture element HTML shim|v it for old IE (pairs with Picturefill.js)
# 	document.createElement("picture");
# </script>
# </link></link></link></meta></meta></meta></head>
# <body class="clubhouse desktop prod" data-app="" data-appearance="light" data-customstylesheet="null" data-edition="en-ww" data-lang="en" data-pagetype="clubhouse" data-site="espn" data-sport="soccer">
# <div class="ad-slot ad-slot-exclusions" data-category-exclusion="true" data-slot-kvps="pos=exclusions" data-slot-type="exclusions"></div><div class="ad-slot ad-slot-overlay" data-out-of-page="true" data-slot-kvps="pos=outofpage" data-slot-type="overlay"></div>
# <!-- abtest data object global -->
# <script type="text/javascript">
# 			var abtestData = {};
#
# 		</script>
# <div id="fb-root"></div>
# <div class="interior secondary tertiary" data-behavior="global_nav_condensed global_nav_full" id="global-viewport">
# <nav data-loadtype="server" id="global-nav-mobile"></nav>
# <div class="menu-overlay-primary"></div>
# <div class="hidden-print" id="header-wrapper">
# <section class="hide-fullbtn" id="global-scoreboard" role="region">
# <button class="scoreboard-hidden-skipnav" data-behavior="scoreboard_skipnav">
#         Skip to navigation
#     </button>
# <div class="wrap">
# <div class="scoreboard-content">
# <div class="scoreboard-dropdown-wrapper scoreboard-menu">
# <!-- mobile dropdown -->
# <div class="league-nav-wrapper league-nav-mobile mobile-dropdown">
# <span class="mobile-arrow"></span>
# <select id="league-nav"></select>
# </div>
# <!-- desktop dropdown -->
# <div class="dropdown-wrapper league-nav-desktop desktop-dropdown" data-behavior="button_dropdown">
# <button class="button button-filter sm dropdown-toggle current-league-name" type="button"></button>
# <ul class="dropdown-menu league-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper conference-menu">
# <!-- mobile dropdown -->
# <div class="conference-nav-wrapper mobile-dropdown">
# <span class="mobile-arrow"></span>
# <select id="conference-nav"></select>
# </div>
# <!-- desktop dropdown -->
# <div class="dropdown-wrapper desktop-dropdown" data-behavior="button_dropdown">
# <button class="button button-filter med dropdown-toggle current-conference-name" type="button"></button>
# <ul class="dropdown-menu conference-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper scores-date-pick">
# <div class="dropdown-wrapper" data-behavior="button_dropdown">
# <button class="button button-filter dropdown-toggle sm selected-date" type="button"></button>
# <ul class="dropdown-menu date-nav med"></ul>
# </div>
# </div>
# <div class="scoreboard-dropdown-wrapper secondary-nav-container hidden"></div>
# <div class="scores-prev controls inactive">&lt;</div>
# <div class="view-full" id="fullbtn"></div>
# <div class="scores-next controls">&gt;</div>
# <div class="scores-carousel">
# <ul id="leagues"></ul>
# </div>
# </div>
# </div>
# </section>
# <header class="espnww-en user-account-management has-search" id="global-header">
# <div class="menu-overlay-secondary"></div>
# <div class="container">
# <a data-route="false" href="#" id="global-nav-mobile-trigger"><span>Menu</span></a><h1><a href="/" name="&amp;lpos=sitenavdefault&amp;lid=sitenav_main-logo">ESPN</a></h1><ul class="tools"><li class="search">
# <a class="icon-font-after icon-search-solid-after" href="#" id="global-search-trigger"></a>
# <div class="global-search" id="global-search">
# <input class="search-box" placeholder="Search Sports, Teams or Players..." type="text"/><input class="btn-search" type="submit"/>
# </div></li><li class="user" data-behavior="favorites_mgmt"></li><li id="scores-link"><a data-route="false" href="#" id="global-scoreboard-trigger">Scores</a></li></ul>
# <div class="alert-container tooltip" data-behavior="edition_alert">
# <div class="grid-row">
# <div class="alert-column">
# <div class="icon-font-before icon-alert01-solid-before">
# <p>You have come to the all new Global edition, for other ESPN editions, click here.</p>
# <a class="icon-font-after icon-close-solid-after" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <nav data-loadtype="server" id="global-nav">
# <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement">
# <li itemprop="name"><a href="/football/" itemprop="url">Football</a></li><li itemprop="name"><a href="/nba/" itemprop="url">NBA</a></li><li itemprop="name"><a href="/nfl/" itemprop="url">NFL</a></li><li itemprop="name"><a href="/cricket/" itemprop="url">Cricket</a></li><li itemprop="name"><a href="/rugby/" itemprop="url">Rugby</a></li><li itemprop="name"><a href="/golf/" itemprop="url">Golf</a></li><li itemprop="name"><a href="/tennis/" itemprop="url">Tennis</a></li><li itemprop="name"><a href="#" itemprop="url">…</a><div><ul class="split"><li itemprop="name"><a href="/esports/" itemprop="url">esports</a></li><li itemprop="name"><a href="/indy-car/" itemprop="url">IndyCar</a></li><li itemprop="name"><a href="/f1/" itemprop="url">F1</a></li><li itemprop="name"><a href="/mlb/" itemprop="url">MLB</a></li><li itemprop="name"><a href="/nhl/" itemprop="url">NHL</a></li><li itemprop="name"><a href="/chess/" itemprop="url">Chess</a></li><li itemprop="name"><a href="/shooting/" itemprop="url">Shooting</a></li><li itemprop="name"><a href="/olympics/" itemprop="url">Olympic Sports</a></li><li itemprop="name"><a href="/wnba/" itemprop="url">WNBA</a></li><li itemprop="name"><a href="/college-football/" itemprop="url">NCAAF</a></li><li itemprop="name"><a href="/mens-college-basketball/" itemprop="url">NCAAM</a></li><li itemprop="name"><a href="/womens-college-basketball/" itemprop="url">NCAAW</a></li><li itemprop="name"><a href="/snooker/" itemprop="url">Snooker</a></li><li itemprop="name"><a href="/racing/nascar/" itemprop="url">NASCAR</a></li><li itemprop="name"><a href="/athletics/" itemprop="url">Athletics</a></li><li itemprop="name"><a href="/boxing/" itemprop="url">Boxing</a></li><li itemprop="name"><a href="/cycling/" itemprop="url">Cycling</a></li><li itemprop="name"><a href="/mma/" itemprop="url">MMA</a></li><li itemprop="name"><a href="/college-sports/" itemprop="url">NCAA</a></li><li itemprop="name"><a href="/endurance/" itemprop="url">Endurance</a></li><li itemprop="name"><a href="/xfl/" itemprop="url">XFL</a></li><li itemprop="name"><a href="http://xgames.com/" itemprop="url">X Games</a></li><li itemprop="name"><a href="http://www.espn.com/specialolympics/" itemprop="url">Special Olympics</a></li></ul></div></li><li class="pillar more-espn"><a href="#">More ESPN</a></li><li class="pillar fantasy"><a href="/fantasy/">Fantasy</a></li></ul>
# </nav>
# <nav data-loadtype="tier-3-server" id="global-nav-secondary">
# <div class="ClubhouseHeader" id="clubhouse-header"><div class="ClubhouseHeader__Container"><div class="ClubhouseHeader__Main"><figure class="Image aspect-ratio ClubhouseHeader__Logo"><div class="Image__Wrapper aspect-ratio--1x1"><picture><source data-srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;w=100&amp;h=100&amp;transparent=true" srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;w=100&amp;h=100&amp;transparent=true"/><img alt="" class="aspect-ratio--object imageLoaded lazyloaded" data-default-src="" data-mptype="image" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;w=100&amp;h=100&amp;transparent=true"/></picture></div></figure><div class="ClubhouseHeader__Content"><h1 class="ClubhouseHeader__Name"><div class="ClubhouseHeader__NameWrapper"><span class="ClubhouseHeader__Location"></span><span class="ClubhouseHeader__DisplayName">LAFC</span></div></h1><div class="ClubhouseHeader__TeamDetails"><a class="btn ClubhouseHeader__Follow button-alt sm">Follow</a><ul class="ClubhouseHeader__Record"><li>1-1-0</li><li>13th in Major League Soccer</li></ul></div></div></div></div></div>
# <div class="global-nav-container">
# <ul class="first-group tertiary"><li class="sub"><a href="/football/club/_/id/18966"><span class="link-text">Home</span><span class="link-text-short">Home</span></a></li><li class="sub"><a href="https://global.espn.com/football/team/fixtures/_/id/18966/lafc"><span class="link-text">Fixtures</span><span class="link-text-short">Fixtures</span></a></li><li class="sub"><a href="https://global.espn.com/football/team/results/_/id/18966/lafc"><span class="link-text">Results</span><span class="link-text-short">Results</span></a></li><li class="sub"><a href="/football/team/squad/_/id/18966/lafc"><span class="link-text">Squad</span><span class="link-text-short">Squad</span></a></li><li class="sub"><a href="/football/team/stats/_/id/18966"><span class="link-text">Statistics</span><span class="link-text-short">Statistics</span></a></li><li class="sub"><a data-pagetype="transfers" href="https://global.espn.com/football/team/transfers/_/id/18966/lafc"><span class="link-text">Transfers</span><span class="link-text-short">Transfers</span></a></li><li class="sub"><a data-page="standings" href="/football/table/_/league/usa.1"><span class="link-text">Table</span><span class="link-text-short">Table</span></a></li><li class="sub external"><a href="http://www.espnfc.co.uk/team/lafc/18966/video"><span class="link-text">Video</span><span class="link-text-short">Video</span></a></li></ul>
# <script type="text/javascript">
# 		var espn = espn || {};
# 		espn.nav = espn.nav || {};
# 		espn.nav.navId = 21959715;
# 		espn.nav.isFallback = false;
#
#
# 			espn.nav.tier2 = {"subNavMenu":{"navigation":{"links":[{"isExternal":false,"shortText":"Football","rel":["sports"],"attributes":{"icon":"soccer"},"text":"Football","href":"/football/","isPremium":false}],"attributes":{"sport_id":"600","root":"soccer"},"text":"Football","title":"Football Menu - Global Edition - Shared with SG","$ref":"/v2/navigation/22300298","items":[{"links":[{"isExternal":false,"shortText":"Scores","rel":["sub"],"text":"Scores","href":"/football/scoreboard","isPremium":false}],"title":"Football Scores","$ref":"/v2/navigation/12020044"},{"links":[{"isExternal":false,"shortText":"Fixtures","rel":["sub"],"text":"Fixtures","href":"/football/fixtures","isPremium":false}],"title":"Football Fixtures & Results","$ref":"/v2/navigation/12020046"},{"links":[{"isExternal":false,"shortText":"Transfers","rel":["sub"],"attributes":{"route":"false"},"text":"Transfers","href":"/football/transfers/","isPremium":false}],"title":"Football Transfers - Global","$ref":"/v2/navigation/22602933"},{"links":[{"isExternal":false,"shortText":"Teams","rel":["none","sub"],"text":"Teams","href":"/football/teams","isPremium":false}],"text":"Teams","title":"Football All Teams Global ","$ref":"/v2/navigation/22348566","items":[{"links":[{"isExternal":false,"shortText":"Arsenal","rel":["team"],"attributes":{"teamId":"359","type":"team","sport":"soccer"},"text":"Arsenal ","href":"/football/club/_/id/359/arsenal","isPremium":false}],"title":"Arsenal - Global","$ref":"/v2/navigation/22355102"},{"links":[{"isExternal":false,"shortText":"Chelsea","rel":["team"],"attributes":{"teamId":"363","type":"team","sport":"soccer"},"text":"Chelsea","href":"/football/club/_/id/363/chelsea","isPremium":false}],"title":"Chelsea - Global","$ref":"/v2/navigation/22355104"},{"links":[{"isExternal":false,"shortText":"Liverpool","rel":["team"],"attributes":{"teamId":"364","type":"team","sport":"soccer"},"text":"Liverpool","href":"/football/club/_/id/364/liverpool","isPremium":false}],"title":"Liverpool - Global","$ref":"/v2/navigation/22355103"},{"links":[{"isExternal":false,"shortText":"Manchester City","rel":["team"],"attributes":{"teamId":"382","type":"team","sport":"soccer"},"text":"Manchester City","href":"/football/club/_/id/382/manchester-city","isPremium":false}],"title":"Manchester City - Global","$ref":"/v2/navigation/22355105"},{"links":[{"isExternal":false,"shortText":"Manchester United","rel":["team"],"attributes":{"teamId":"360","type":"team","sport":"soccer"},"text":"Manchester United ","href":"/football/team/_/id/360/Manchester-United/","isPremium":false}],"title":"Manchester United - Global","$ref":"/v2/navigation/22355136"},{"links":[{"isExternal":false,"shortText":"Tottenham Hotspur","rel":["team"],"attributes":{"teamId":"367","type":"team","sport":"soccer"},"text":"Tottenham Hotspur","href":"/football/club/_/id/367/tottenham-hotspur","isPremium":false}],"title":"Tottenham Hotspur - Global","$ref":"/v2/navigation/22355132"},{"links":[{"isExternal":false,"shortText":"Atletico Madrid","rel":["team"],"attributes":{"teamId":"1068","type":"team","sport":"soccer"},"text":"Atletico Madrid","href":"/football/team/_/id/1068/Atletico-Madrid/","isPremium":false}],"title":"Atletico Madrid - Global","$ref":"/v2/navigation/22355134"},{"links":[{"isExternal":false,"shortText":"Barcelona","rel":["team"],"attributes":{"teamId":"83","type":"team","sport":"soccer"},"text":"Barcelona","href":"/football/team/_/id/83/Barcelona/","isPremium":false}],"title":"FC Barcelona - Global","$ref":"/v2/navigation/22355135"},{"links":[{"isExternal":false,"shortText":"Real Madrid","rel":["team"],"attributes":{"teamId":"86","type":"team","sport":"soccer"},"text":"Real Madrid","href":"/football/team/_/id/86/","isPremium":false}],"title":"Real Madrid - Global","$ref":"/v2/navigation/22355133"},{"links":[{"isExternal":false,"shortText":"Juventus","rel":["team"],"attributes":{"teamId":"111","type":"team","sport":"soccer"},"text":"Juventus","href":"/football/team/_/id/111/","isPremium" ...
#
#
# 			espn.nav.tier3 = {"subNavMenu":{"navigation":{"links":[{"isExternal":false,"shortText":"Football","rel":["sports"],"attributes":{"icon":"soccer"},"text":"Football","href":"/football/","isPremium":false}],"attributes":{"root":"soccer"},"text":"Football","title":"Soccer Clubhouse Nav Redesign","$ref":"/v2/navigation/12294454","items":[{"links":[{"isExternal":false,"shortText":"Home","rel":["sub"],"text":"Home","href":"/football/club/_/id/18966","isPremium":false}],"title":"Soccer Clubhouse Home","$ref":"/v2/navigation/12386737"},{"links":[{"isExternal":false,"shortText":"Fixtures","rel":["sub"],"text":"Fixtures","href":"https://global.espn.com/football/team/fixtures/_/id/18966/lafc","isPremium":false}],"title":"Football Clubhouse Fixtures","$ref":"/v2/navigation/23854062"},{"links":[{"isExternal":false,"shortText":"Results","rel":["sub"],"text":"Results","href":"https://global.espn.com/football/team/results/_/id/18966/lafc","isPremium":false}],"title":"Football Clubhouse Results","$ref":"/v2/navigation/23854060"},{"links":[{"isExternal":false,"shortText":"Squad","rel":["sub"],"text":"Squad","href":"/football/team/squad/_/id/18966/lafc","isPremium":false}],"title":"Football Clubhouse Squad","$ref":"/v2/navigation/23854289"},{"links":[{"isExternal":false,"shortText":"Statistics","rel":["sub"],"text":"Statistics","href":"/football/team/stats/_/id/18966","isPremium":false}],"title":"Soccer Clubhouse Stats","$ref":"/v2/navigation/12294592"},{"links":[{"isExternal":false,"shortText":"Transfers","rel":["sub"],"attributes":{"pagetype":"transfers"},"text":"Transfers","href":"https://global.espn.com/football/team/transfers/_/id/18966/lafc","isPremium":false}],"title":"Football Clubhouse Transfers","$ref":"/v2/navigation/23854067"},{"links":[{"isExternal":false,"shortText":"Table","rel":["sub"],"attributes":{"page":"standings"},"text":"Table","href":"/football/table/_/league/usa.1","isPremium":false}],"title":"Soccer Clubhouse Table - Copy","$ref":"/v2/navigation/20993225"},{"links":[{"isExternal":true,"shortText":"Video","rel":["sub"],"text":"Video","href":"http://www.espnfc.co.uk/team/lafc/18966/video","isPremium":false}],"title":"Soccer Clubhouse Video","$ref":"/v2/navigation/12299748"}]},"navId":12294454,"fallback":false},"title":"LAFC","titleShort":"LAFC","sub":"13th in Major League Soccer","sub2":"","logo":"https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&h=150&w=150","league":"soccer","team":{"teamId":"18966","sportId":"600","leagueId":"770","teamName":"LAFC","teamLocation":"","logo":"https://a.espncdn.com/i/teamlogos/soccer/500/18966.png","recordSummary":"1-1-0","standingSummary":"13th in Major League Soccer"},"url":"/football/club/_/id/18966/lafc","type":"clubhouse"};
#
#
# 	</script>
# </div>
# </nav>
# </header>
# </div>
# <section id="pane-main">
# <div data-id="clubhouse" id="custom-nav"></div>
# <div class="ad-slot ad-slot-wallpaper" data-collapse-before-load="true" data-exclude-bp="s,m" data-slot-kvps="pos=wallpaper" data-slot-type="wallpaper"></div>
# <div class="ad-banner-wrapper"><div class="ad-slot ad-slot-banner ad-wrapper" data-slot-kvps="pos=banner" data-slot-type="banner"></div></div>
# <section id="main-container">
# <div class="main-content layout-abc">
# <section class="col-a chk-height"><section class="club-schedule" data-module="schedule"><h1><p>2020 Schedule</p><span>All times <span data-behavior="date_timezone" data-usebrackets="false">ET</span></span></h1><ul><ul><li><header class="game-strip post soccer bt-sport"><a class="competitors" href="/football/matchstats?gameId=561768"><div class="team tied team-a possession"><div class="team__content"><div class="team__banner" style="background-color: #;"><div class="team__banner__wrapper"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40"/></picture></div></div><div class="team-container"><div class="team-info"><div class="team-info-wrapper"><span class="rank"></span><span class="team-name"><span class="long-name"></span><span class="short-name">VAN</span><span class="abbrev">VAN</span></span></div><span class="record"></span></div><div class="team-info-logo"><div class="logo"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/9727.png&amp;h=40&amp;w=40"/></picture></div></div></div></div></div> <div class="game-status"><span class="game-time">PPD</span><span class="aggregate"></span></div> <div class="team tied team-b"><div class="team__content"><div class="team__banner" style="background-color: #;"><div class="team__banner__wrapper"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40"/></picture></div></div><div class="team-container"><div class="team-info-logo"><div class="logo"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png&amp;h=40&amp;w=40"/></picture></div></div><div class="team-info"><div class="team-info-wrapper"><span class="rank"></span><span class="team-name"><span class="long-name"></span><span class="short-name">LAFC</span><span class="abbrev">LAFC</span></span></div><span class="record"></span></div></div></div></div></a></header><div class="game-details footer soccer post"><div class="wrap"><div class="league-name-short game-status">Major League Soccer</div><div class="league-name-short game-status mobile">Major League Soccer</div></div></div></li><li><header class="game-strip post soccer bt-sport"><a class="competitors" href="/football/matchstats?gameId=561786"><div class="team tied team-a possession"><div class="team__content"><div class="team__banner" style="background-color: #;"><div class="team__banner__wrapper"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/185.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/185.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/185.png&amp;h=40&amp;w=40"/></picture></div></div><div class="team-container"><div class="team-info"><div class="team-info-wrapper"><span class="rank"></span><span class="team-name"><span class="long-name"></span><span class="short-name">DAL</span><span class="abbrev">DAL</span></span></div><span class="r ...
# </div></article><!--set: espnww-en_us_clubhouse_soccer_4072304_2020-03-11T16:33:45Z_false_true_false_desktop_full_11--><!--espnww-en_us_clubhouse_soccer_4072304_2020-03-11T16:33:45Z_false_true_false_desktop_full_11--><article class="news-feed-item video-standalone video" data-id="4072304"><a class="story-link" data-id="4072304" data-popup-href="https://global.espn.com/soccer/major-league-soccer/19/video/4072304" data-sport="soccer" href="/football/major-league-soccer/19/video/4072304" name="&amp;lpos=soccer:feed:xx:news"></a><figure class="feed-item-figure video" data-cerebro-id="5e6912a4ca84b751fe440201" data-source="intl" data-video="native,640,360,4072304,whitelist-SX|AI|BB|BM|MX|KY|AW|BZ|FK|TC|NZ|BO|GF|MQ|US|AQ|VC|DO|PE|HT|BS|MS|CR|GT|VE|AU|BR|KN|UY|CW|GP|GY|TT|VG|SV|NI|SR|HN|EC|GD|JM|CL|PA|AG|AR|BQ|LC|PY|"><div class="img-wrap"><a data-mptype="image" data-sport="soccer" href="/football/major-league-soccer/19/video/4072304" name="&amp;lpos=soccer:feed:xx:news"><picture><source data-srcset="https://a.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0311%2Fint_200311_pub2tag_twellman_on_philadelphia%2Fint_200311_pub2tag_twellman_on_philadelphia.jpg&amp;w=375&amp;h=150&amp;scale=crop&amp;cquality=80&amp;location=origin, https://a.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0311%2Fint_200311_pub2tag_twellman_on_philadelphia%2Fint_200311_pub2tag_twellman_on_philadelphia.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(max-width: 375px)"/><source data-srcset="https://a.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0311%2Fint_200311_pub2tag_twellman_on_philadelphia%2Fint_200311_pub2tag_twellman_on_philadelphia.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=80&amp;location=origin&amp;format=jpg, https://a.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0311%2Fint_200311_pub2tag_twellman_on_philadelphia%2Fint_200311_pub2tag_twellman_on_philadelphia.jpg&amp;w=1296&amp;h=518&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(min-width: 376px)"/><img class="lazyload" data-default-src="https://a.espncdn.com/media/motion/ESPNi/2020/0311/int_200311_pub2tag_twellman_on_philadelphia/int_200311_pub2tag_twellman_on_philadelphia.jpg" data-image-container=".feed-item-figure"/></picture></a><span class="video-play-button restricted" data-id="4072304" data-playtxt="PLAY"></span></div><figcaption><div class="caption-wrapper"><div class="text-container"><span class="headline">Twellman: Philadelphia just as impressive as LAFC in 3-3 draw (1:28)</span></div></div></figcaption></figure><div class="text-container no-headlines"><div class="news-feed_item-meta"><span class="timestamp">8d</span></div></div></article><div class="ad-slot-inview ad-slot-mobile-incontent ad-wrapper" data-include-bp="s" data-refresh-if-visible="true" data-slot-kvps="pos=incontent,loc=news" data-slot-type="incontent"></div><!--set: espnww-en_us_clubhouse_soccer_4071237_2020-03-09T20:53:54Z_false_true_false_desktop_full_11--><!--espnww-en_us_clubhouse_soccer_4071237_2020-03-09T20:53:54Z_false_true_false_desktop_full_11--><article class="news-feed-item video-standalone video" data-id="4071237"><a class="story-link" data-id="4071237" data-popup-href="https://global.espn.com/soccer/video/latest-videos/600/video/4071237" data-sport="soccer" href="/football/video/latest-videos/600/video/4071237" name="&amp;lpos=soccer:feed:xx:major-league-soccer:news"></a><figure class="feed-item-figure video" data-cerebro-id="5e66aabdca84b751fe3eb2d6" data-source="intl" data-video="native,640,360,4071237,whitelist-SX|AI|BB|BM|MX|KY|AW|BZ|FK|TC|NZ|BO|GF|MQ|US|AQ|VC|DO|PE|HT|BS|MS|CR|GT|VE|AU|BR|KN|UY|CW|GP|GY|TT|VG|SV|NI|SR|HN|EC|GD|JM|CL|PA|AG|AR|BQ|LC|PY|"><div class="img-wrap"><a data-mptype="image" data-sport="soccer" href="/football/video/latest-videos/600/video/4071237" name="&amp;lpos=soccer:feed:xx:major-league-soccer:news"><picture><source data-sr ...
# </div></article><div class="ad-slot-inview ad-slot-native ad-wrapper" data-slot-kvps="pos=native,loc=news" data-slot-type="native"></div><!--set: espnww-en_us_clubhouse_soccer_4070793_2020-03-09T05:05:38Z_false_true_false_desktop_full_11--><!--espnww-en_us_clubhouse_soccer_4070793_2020-03-09T05:05:38Z_false_true_false_desktop_full_11--><article class="news-feed-item video-standalone video" data-id="4070793"><a class="story-link" data-id="4070793" data-popup-href="https://global.espn.com/soccer/major-league-soccer/19/video/4070793" data-sport="soccer" href="/football/major-league-soccer/19/video/4070793" name="&amp;lpos=soccer:feed:xx:news"></a><figure class="feed-item-figure video" data-cerebro-id="5e65ce42ca84b751fe3bea3c" data-source="intl" data-video="native,640,360,4070793,whitelist-SX|AI|BB|BM|MX|KY|AW|BZ|FK|TC|NZ|BO|GF|MQ|US|AQ|VC|DO|PE|HT|BS|MS|CR|GT|VE|AU|BR|KN|UY|CW|GP|GY|TT|VG|SV|NI|SR|HN|EC|GD|JM|CL|PA|AG|AR|BQ|LC|PY|"><div class="img-wrap"><a data-mptype="image" data-sport="soccer" href="/football/major-league-soccer/19/video/4070793" name="&amp;lpos=soccer:feed:xx:news"><picture><source data-srcset="https://a1.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0309%2Fint_200309_pub2tag_lafcunion_HL%2Fint_200309_pub2tag_lafcunion_HL.jpg&amp;w=375&amp;h=150&amp;scale=crop&amp;cquality=80&amp;location=origin, https://a1.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0309%2Fint_200309_pub2tag_lafcunion_HL%2Fint_200309_pub2tag_lafcunion_HL.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(max-width: 375px)"/><source data-srcset="https://a1.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0309%2Fint_200309_pub2tag_lafcunion_HL%2Fint_200309_pub2tag_lafcunion_HL.jpg&amp;w=768&amp;h=307&amp;scale=crop&amp;cquality=80&amp;location=origin&amp;format=jpg, https://a1.espncdn.com/combiner/i?img=%2Fmedia%2Fmotion%2FESPNi%2F2020%2F0309%2Fint_200309_pub2tag_lafcunion_HL%2Fint_200309_pub2tag_lafcunion_HL.jpg&amp;w=1296&amp;h=518&amp;scale=crop&amp;cquality=40&amp;location=origin&amp;format=jpg 2x" media="(min-width: 376px)"/><img class="lazyload" data-default-src="https://a.espncdn.com/media/motion/ESPNi/2020/0309/int_200309_pub2tag_lafcunion_HL/int_200309_pub2tag_lafcunion_HL.jpg" data-image-container=".feed-item-figure"/></picture></a><span class="video-play-button restricted" data-id="4070793" data-playtxt="PLAY"></span></div><figcaption><div class="caption-wrapper"><div class="text-container"><span class="headline">LAFC &amp; Philadelphia play to thrilling draw (2:11)</span></div></div></figcaption></figure><div class="text-container no-headlines"><div class="news-feed_item-meta"><span class="timestamp">11d</span></div></div></article><!--set: espnww-en_us_clubhouse_soccer_footballid561813_2020-03-08T06:14:34Z_false_true_false_desktop_full_11--><!--espnww-en_us_clubhouse_soccer_footballid561813_2020-03-08T06:14:34Z_false_true_false_desktop_full_11--><article class="news-feed-item no-images" data-id="footballid561813"><a class="story-link" data-id="footballid561813" data-popup-href="https://global.espn.com/football/preview?gameId=561813" data-sport="soccer" href="/football/preview?gameId=561813" name="&amp;lpos=soccer:feed:xx:major-league-soccer:news"></a><div class="text-container no-headlines"><div class="item-info-wrap"><div class="news-feed_item-meta"><span class="timestamp">12d</span><span class="author">Reuters</span></div><h1><a class="realStory" data-mptype="story" data-sport="soccer" href="/football/preview?gameId=561813" name="&amp;lpos=soccer:feed:xx:major-league-soccer:news">Vela in spotlight as LAFC host Union</a></h1><p>Los Angeles FC forward Carlos Vela has an MLS MVP Award on the shelf back home, and he enters Sunday's home game against the Philadelphia Union look</p></div>
# ...
# 					useStatic: false,
# 					version: 2,
# 					topEventsId: 4379198,
# 					topSoccerId: 24781898
#
#
#
#
#
# 				},
# 				data: {"sports":[{"leagues":[{"name":"custom","id":"-1","abbreviation":"custom","slug":"custom","events":[{"notes":[{"text":"See how the coronavirus is affecting sports all around the world.","type":"editorial"}],"appLinks":[],"name":"Coronavirus Cancellations","description":"Coronavirus Cancellations","links":[{"rel":["desktop","custom"],"href":"https://www.espn.com/espn/story/_/id/28871525/coronavirus-cancellations-reactions-sports","text":"Full Coverage"}],"priority":0}]}],"name":"custom","id":"-1","slug":"custom"},{"uid":"s:600","leagues":[{"uid":"s:600~l:3906","smartdates":["2020-03-18T07:00Z","2020-03-20T07:00Z","2020-03-21T07:00Z"],"name":"Australian A-League","id":"3906","tag":"aus.1","abbreviation":"A Lge","shortName":"A-League","slug":"aus.1","isTournament":false,"events":[{"date":"2020-03-20T06:30:00Z","commentaryAvailable":false,"timeValid":true,"link":"http://global.espn.com/football/match?gameId=555948","playByPlayAvailable":true,"addedClock":0,"uid":"s:600~l:3906~e:555948~c:555948","competitors":[{"alternateColor":"104C94","competitionIdPrevious":"555953","color":"f5fe05","displayName":"Central Coast Mariners","type":"team","abbreviation":"CCM","competitionIdNext":"555943","uid":"s:600~t:5325","homeAway":"home","score":"","winner":false,"logoDark":"https://a.espncdn.com/i/teamlogos/soccer/500-dark/5325.png","form":"LLLLL","record":"4-1-16","name":"CC Mariners","logo":"https://a.espncdn.com/i/teamlogos/soccer/500/5325.png","location":"Central Coast Mariners","id":"5325","order":0,"isNational":false,"group":"1"},{"alternateColor":"fafafc","competitionIdPrevious":"555951","color":"87cefa","displayName":"Melbourne City FC","type":"team","abbreviation":"MBC","competitionIdNext":"555937","uid":"s:600~t:11143","homeAway":"away","score":"","winner":false,"logoDark":"https://a.espncdn.com/i/teamlogos/soccer/500-dark/11143.png","form":"DWWLW","record":"11-4-6","name":"Melbourne C","logo":"https://a.espncdn.com/i/teamlogos/soccer/500/11143.png","location":"Melbourne City FC","id":"11143","order":1,"isNational":false,"group":"1"}],"appLinks":[],"seasonTypeHasGroups":false,"season":2019,"links":[{"rel":["summary","desktop","event"],"href":"http://global.espn.com/football/match?gameId=555948","text":"Summary"},{"rel":["stats","desktop","event"],"href":"http://global.espn.com/football/matchstats?gameId=555948","text":"Statistics"},{"rel":["standings","desktop","event"],"href":"http://global.espn.com/football/table/_/league/aus.1","text":"Table"}],"id":"555948","recent":false,"group":{"groupId":"1","name":"Regular Season","abbreviation":"2019 A-League","shortName":"2019 A-LEAGUE"},"summary":"3/20 - 2:30 AM EDT","seasonType":"1","competitionId":"555948","period":0,"gamecastAvailable":true,"clock":"0'","priority":1,"seasonEndDate":"2020-04-28T03:59:00Z","onWatch":false,"seasonStartDate":"2019-07-01T04:00:00Z","name":"2019-20 Australian A League","location":"Central Coast Stadium","shortName":"2019-20 Australian A League","fullStatus":{"period":0,"displayClock":"0'","clock":0,"type":{"name":"STATUS_SCHEDULED","description":"Scheduled","id":"1","state":"pre","completed":false,"detail":"Fri, March 19th at 2:30 AM EDT","shortDetail":"3/20 - 2:30 AM EDT"},"addedClock":0},"status":"pre"},{"date":"2020-03-20T08:30:00Z","commentaryAvailable":false,"timeValid":true,"link":"http://global.espn.com/football/match?gameId=555934","playByPlayAvailable":true,"addedClock":0,"uid":"s:600~l:3906~e:555934~c:555934","competitors":[{"alternateColor":"d3d3d3","competitionIdPrevious":"555953","color":"F5A12D","displayName":"Brisbane Roar","type":"team","abbreviation":"BRI","competitionIdNext":"555945","uid":"s:600~t:5326","homeAway":"home","score":"","winner":false,"logoDark":"https://a.espncdn.com/i/teamlogos/soccer/500-dark/5326.png","form":"WWLDW","record":"9-5-7","name":"Brisbane","logo":"https://a.espncdn.com/i/teamlogos/soccer/500/5326.png","location":"Brisbane Roar","id":"5326","order":0,"isNational":false,"group":"1"},{"alternateColor":"ffff ...
# 				queue: [],
# 				indexTopics: {"supportedPubKeys":{"espn-es-co-soccer-index":true,"espnin-en-soccer-index":true,"espn-es-ar-frontpage-index":true,"espn-es-cl-soccer-index":true,"espnin-en-cricket-index":true,"espnuk-en-rugby-index":true,"espnau-en-frontpage-index":true,"espnuk-en-tennis-index":true,"espn-es-cl-frontpage-index":true,"espnuk-en-frontpage-index":true,"espn-en-ncaa-index":true,"espnin-en-frontpage-index":true,"espn-en-tennis-index":true,"espn-es-ar-rpm-index":true,"espn-es-mx-soccer-index":true,"espn-en-womenbb-index":true,"espnuk-en-cricket-index":true,"espnin-en-tennis-index":true,"espn-es-ve-soccer-index":true,"espn-es-ar-soccer-index":true,"espn-es-us-frontpage-index":true,"espn-es-ar-tennis-index":true,"espn-es-co-frontpage-index":true,"espn-es-us-other-sports-index":true,"espn-es-us-soccer-index":true,"espnau-en-rugby-index":true,"espnza-en-frontpage-index":true,"espnuk-en-soccer-index":true,"espn-en-frontpage-index":true,"17784479":true,"espn-es-ve-frontpage-index":true,"espn-es-mx-frontpage-index":true,"espn-es-ar-rugby-index":true,"espnza-en-soccer-index":true,"espn-en-rpm-index":true,"espn-en-frontpage-grant-test-index":true}}
# 			};
#
#
#
# 		</script>
# <script type="text/javascript">jQuery.subscribe('espn.defer.end', function () { espn.scoreboard.init(); });</script>
# <script type="text/javascript">
# 		    (function() {
# 		      espn.track = espn.track || {}
# 		      espn.track.ctoPofItems = [{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"1,1","nowId":"16-4075350","pzncon_personalized":"N","addedBy":"sCore","id":4075350,"isPcc":false,"headline":"Top 5 MLS goals so far: Vela only claims 1 spot","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"2,1","nowId":"16-4074005","pzncon_personalized":"N","addedBy":"sCore","id":4074005,"isPcc":false,"headline":"Twellman: MLS season not jeopardized like other leagues","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"3,1","nowId":"16-4073261","pzncon_personalized":"N","addedBy":"sCore","id":4073261,"isPcc":false,"headline":"Mexico games in U.S. called off; CCL suspended","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"4,1","nowId":"16-4072304","pzncon_personalized":"N","addedBy":"sCore","id":4072304,"isPcc":false,"headline":"Twellman: Philadelphia just as impressive as LAFC in 3-3 draw","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"5,1","nowId":"16-4071237","pzncon_personalized":"N","addedBy":"sCore","id":4071237,"isPcc":false,"headline":"39 MLS goals in 90 seconds","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"6,1","nowId":"16-4070795","pzncon_personalized":"N","addedBy":"sCore","id":4070795,"isPcc":false,"headline":"LAFC come back 3 times to force draw with Philadelphia Union","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"6,2","nowId":"","pzncon_personalized":"N","addedBy":"sCore","id":4062325,"isPcc":false,"headline":"MLS at 25: 25 predictions for the next 25 years","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"6,3","nowId":"","pzncon_personalized":"N","addedBy":"sCore","id":4070786,"isPcc":false,"headline":"U.S. squad names MLS-heavy Olympic roster","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"7,1","nowId":"16-4070793","pzncon_personalized":"N","addedBy":"sCore","id":4070793,"isPcc":false,"headline":"LAFC & Philadelphia play to thrilling draw","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"8,1","nowId":"16-4069749","pzncon_personalized":"N","addedBy":"sCore","id":4069749,"isPcc":false,"headline":"Vela in spotlight as LAFC host Union","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"9,1","nowId":"16-4067530","pzncon_personalized":"N","addedBy":"sCore","id":4067530,"isPcc":false,"headline":"Chicharito: Vela more talented than Cuauhtemoc","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"9,2","nowId":"","pzncon_personalized":"N","addedBy":"sCore","id":4066203,"isPcc":false,"headline":"Chicharito: Mexico players need to go to Europe","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"9,3","nowId":"","pzncon_personalized":"N","addedBy":"sCore","id":4065742,"isPcc":false,"headline":"Marquez: MLS more attractive to Mexico's best","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Story","pzncon_curated":"N","pzncon_slot_position":"9,4","nowId":"","pzncon_personalized":"N","addedBy":"sCore","id":4052620,"isPcc":false,"headline":"Forget VAR: Meet Mexico's GoPro referee, taking video technology on to the pitch","pzncon_reason":""},{"pzncon_presentation_type":"null, null, Media","pzncon_curated":"N","pzncon_slot_position":"10,1","nowId":"16-4065480","pzncon_personalized":"N","addedBy":"sCore","id":4065480,"isPcc":false,"headline" ...
#
# 		    })();
# 		  </script>
# <script>
# 	(function() {
# 		function loadDefer() {
# 			var deferScripts = [
# 				'https://a.espncdn.com/redesign/0.486.8/js/espn-defer.js',
# 				'https://a.espncdn.com/redesign/0.486.8/js/espn-defer-low.js'
# 			];
#
# 			$.when(deferScripts.map(function (script) {
# 				var deferred = $.Deferred();
# 				$.getScriptCache(script, deferred.resolve);
# 				return deferred;
# 			})).done(function () {
# 				if(espn.siteType === 'data-lite' && typeof espn.ads.loadGPT === 'function') {
# 					espn.ads.loadGPT();
# 				}
# 			});
# 		}
#
# 		if(window.espn.loadType === "loadEnd" && espn_ui.deviceType !== 'desktop') {
# 			var race = [];
# 			$.when(function () {
# 				var deferred = $.Deferred();
# 				$(window).load(deferred.resolve);
# 				if(espn.siteType !== 'data-lite') {
# 					setTimeout( deferred.resolve, 5000 );
# 				}
# 				return deferred;
# 			}()).then(loadDefer)
#
# 		}else{
# 			loadDefer();
# 		}
#
# 	})();
# 	</script>
# <script>espn_ui.Helpers.translate.init();</script>
# <script type="text/javascript">
# 				var data = {"omniture":{"league":"no+league","countryRegion":"en-ww","hier1":"soccer:teams:clubhouse","section":"soccer","pageName":"soccer:teams:clubhouse","sportsInfo":"soccer:teamid=18966-lafc","sections":"soccer:teams","site":"espnww","premium":"premium-no","convrSport":"soccer","pageURL":"global.espn.com/football/team/_/id/18966/lafc","lang":"en_ww","contentType":"clubhouse","sport":"soccer","account":"wdgespcom","siteType":"full","prop58":"isIndex=false"},"chartbeat":{"loadPubJS":false,"path":"/football/team/_/id/18966/lafc","zone":"global.espn.com.ww.soccer","domain":"global.espn.com","loadVidJS":true,"title":"LAFC  News and Scores - ESPN","sections":"soccer","authors":"clubhouse"},"qualtrics":false,"nielsen":{"espnuk":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnau":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"fantasy":{"apid":"P302B69D5-F1DD-4E7A-BF8D-3E60F0EB5E5A","vc":"c07"},"espndeportes":{"apid":"P890E2723-EDBC-4CCE-96BA-F35EA3E50650","vc":"c02"},"espnfc":{"apid":"PE6995AAE-0C49-4372-B5E7-54C61BFE2AA5","vc":"c03"},"espnww":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"general":{"ci":"us-600140","assetid":"N/A","segB":"N/A","sfcode":"dcr","segA":"N/A","section":"N/A","segC":"N/A","apn":"espnCOM"},"espnza":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"espnin":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"watchespn":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"},"cricinfo":{"apid":"PED8CDAC2-F114-41BE-8B98-AFA06FAEA06E","vc":"c04"},"espnbr":{"apid":"P07264C85-15CD-4A80-8E56-B5BFA6D93296","vc":"b01"}},"ABTest":{"environment":"prod","tScript":"https://a.espncdn.com/prod/scripts/analytics/at.r3.js","oScript":"https://cdn.optimizely.com/js/310987714.js","targetURLs":[{"regexp":"(/)","site":"espn.co.uk","flag":true},{"regexp":"(/.*)","site":"www.espn.com","flag":true}],"domain":"global.espn.com","host":"global.espn.com","raw":"{\"fastcast\":{\"placements\":{\"/nba/index\":\"true\",\"^/.+$\":\"false\",\"/ncf/index\":\"true\"},\"enabled\":false,\"script\":\"https://a.espncdn.com/combiner/c?js=analytics/espn.fastcastTracking.4.js\"},\"optimizely\":{\"oldscript\":\"https://a.espncdn.com/sports/optimizely.js\",\"placements\":[],\"enabled\":false,\"script\":\"https://cdn.optimizely.com/js/310987714.js\"},\"target\":{\"placements\":[{\"regexp\":\"(/)\",\"site\":\"espn.co.uk\",\"flag\":true},{\"regexp\":\"(/.*)\",\"site\":\"www.espn.com\",\"flag\":true}],\"enabled\":true,\"script\":\"https://a.espncdn.com/prod/scripts/analytics/at.r3.js\"}}","optimizely":false,"target":true,"optimizelyURLs":[]},"isFeaturePhone":false,"device":"desktop","cto":false};
# 				var espn = espn || {};
# 				espn.track = espn.track || {};
# 				espn.track.data = data;
# 			</script>
# <!-- SiteCatalyst code version: AppMeasurement 1.0 Copyright 1996-2013 Adobe, Inc. -->
# <script type="text/javascript">
#
#
# 	if (typeof s_omni === 'undefined') {
# 		jQuery(function($){
# 			$.getScriptCache("https://a.espncdn.com/redesign/0.486.8/js/espn-analytics.js", 				function() {					var deferEvent = "user.parsed",						initOnLoad = null || false,						timeoutID;
# 					function initTrack(){						if (typeof espn.track.init === 'function') {							window.clearTimeout(timeoutID);														$.unsubscribe([deferEvent, initTrack]);
# 							espn.track.init(data);						}					}										if(initOnLoad || window.espn_ui.userParsed){						initTrack();					}					else {						$.subscribe(deferEvent, initTrack);                        timeoutID = window.setTimeout(initTrack, 5000);					}				}				);
# 		});
# 	}
#
# 	</script>
# <!-- End SiteCatalyst code version: AppMeasurement 1.0 -->
# <script>
#            var espn = espn || {};
#            espn.ads = espn.ads || {};
#            espn.shellParams = espn.shellParams || {};
#            espn.shellParams.excludeTVEProviders = false
#
#
#         </script>
# </body>
# </html>
# <script>
# 	(function() {
# 		var espn = window.espn || {};
# 		espn.clubhouse = espn.clubhouse || {};
# 		espn.clubhouse.teamName = "lafc";
# 	})();
# </script>

# %%
# find the body of the webpage
[type(item) for item in list(lafc_soup.children)]

lafc_body=list(lafc_soup.children)[3]
lafc_body

#find the fixture data
lafc_fixtures=lafc_body.findAll("section",{"class","col-b"})[0]

#find game webpage
lafc_games=lafc_fixtures.findAll("a",{"class","competitors"})


#create a list of LAFC game Id's
lafc_game_id=[]
for game in lafc_games:
    if game.has_attr("href"):
        lafc_game_id.append(game["href"][-6:])
        
print(lafc_game_id)
# Out:
# ['560836', '560829', '560541', '561813', '569598', '569593', '561794', '561786', '561768']

# %% [markdown]
# <b><i>Looking at the list of game id's it seems like I have only been able to pull game id's from a few of LAFC's games. Upon further inspection of the webpage I used at the beginning, it looks like these are game id's from only the 2020 season which is actually the game Id's that I do not want. It also looks like I have included CONCACAF Champions League games which at this point, I might or might not want to include.</b> </i>

# %%
lafc_games[0]
# Out:
# <a class="competitors" href="/football/matchstats?gameId=560836"><div class="team team-a"><div class="team__content"><div class="team__banner"><div class="team__banner__wrapper"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40"/></picture><svg class="team__svg team__svg--primary" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><lineargradient gradienttransform="translate(-5 -710)" gradientunits="userSpaceOnUse" id="linear-gradient" x1="108.61" x2="90.78" y1="752.49" y2="770.32"><stop offset="0" stop-opacity="0"></stop><stop offset="1"></stop></lineargradient></defs><polygon class="team__stroke" points="81 80 80 80 0 0 1 0 81 80"></polygon><polygon class="team__gradient" points="170.1 80 122.1 80 42.1 0 90.1 0 170.1 80"></polygon></svg><svg class="team__svg team__svg--left" data-name="Layer 1" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg"><polygon class="team__left" points="0 80 80 80 0 0 0 80"></polygon></svg><svg class="team__svg team__svg--right" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><polygon class="team__right" points="176 0 96 0 176 80 176 0"></polygon></svg></div></div><div class="team-container"><div class="team-info"><div class="team-info-wrapper"><span class="team-name"><span class="short-name">LEO</span><span class="abbrev">LEO</span></span></div></div><div class="team-info-logo"><div class="logo"><picture><source srcset="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40"/><img class="team-logo" data-default-src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40" src="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/228.png&amp;h=40&amp;w=40"/></picture></div></div></div><div class="score-container"><span class="score icon-font-after">2</span></div></div></div> <div class="game-status"><span class="game-date">18/2</span><span class="game-time">FT</span></div> <div class="team team-b"><div class="team__content"><div class="team__banner"><div class="team__banner__wrapper"><picture><source srcset="https://a.espncdn.com/i/teamlogos/soccer/500/18966.png"/><img class="team-logo" data-default-src="https://a.espncdn.com/i/teamlogos/soccer/500/18966.png" src="https://a.espncdn.com/i/teamlogos/soccer/500/18966.png"/></picture><svg class="team__svg team__svg--primary" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><lineargradient gradienttransform="translate(-5 -710)" gradientunits="userSpaceOnUse" id="linear-gradient" x1="108.61" x2="90.78" y1="752.49" y2="770.32"><stop offset="0" stop-opacity="0"></stop><stop offset="1"></stop></lineargradient></defs><polygon class="team__stroke" points="81 80 80 80 0 0 1 0 81 80"></polygon><polygon class="team__gradient" points="170.1 80 122.1 80 42.1 0 90.1 0 170.1 80"></polygon></svg><svg class="team__svg team__svg--left" data-name="Layer 1" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg"><polygon class="team__left" points="0 80 80 80 0 0 0 80"></polygon></svg><svg class="team__svg team__svg--right" viewbox="0 0 176 80" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><polygon class="team__right" points="176 0 96 0 176 80 176 0"></polygon></svg></div></div><div class="score-container"><span class="score icon-font-before">0</span></div><div class="team-container"><div class="team-info-logo"><div class="logo"><picture><source srcset="https://a.espncdn.com/i/teamlogos/soccer/500/18966.png"/><img class="team-logo" data-default-src="https://a.espncdn.com/i/teamlogos/soccer/500/18966.png" src="https://a.espncdn.c ...

# %%
#rename lafc_game_id list to 2020_lafc_game_id, Code is in comments below.

    ##lafc_game_id_2020 = []
    ##lafc_game_id_2020=lafc_game_id
    ##del(lafc_game_id)
    
lafc_game_id_2020
# Out:
# ['560836',
#  '560829',
#  '560541',
#  '561813',
#  '569598',
#  '569593',
#  '561794',
#  '561786',
#  '561768']

# %% [markdown]
# #### 1.b Reworking the scraper above to be able to pull all game data for LAFC

# %%
#create a page and us beautiful soup to parse out the content
lafc_page= requests.get("https://www.espn.com/soccer/team/results/_/id/18966/season")

lafc_soup= BeautifulSoup(lafc_page.content, "html.parser")
lafc_soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- ESPNFITT | 4d4b5641d13b | 3596 | 1d4236e078642a9e7f7732436b3c1c306ce20400 | Thu, 19 Mar 2020 22:53:16 GMT -->
# <script type="text/javascript">
#         ;(function(){
#             function gc(n){var r=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return r?r[2]:null}function sc(n){document.cookie=n}function smpl(n){var r=n/100;return!!r&&Math.random()<=r}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;
#             _nr && window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=x.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c] ...
#         })();
#     </script>
# <title data-react-helmet="true">LAFC Results | ESPN</title>
# <meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" name="description"/><meta content="LAFC results, LAFC news, LAFC videos, LAFC stats, LAFC standings, live games LAFC" data-react-helmet="true" name="keywords"/><meta content="116656161708917" data-react-helmet="true" property="fb:app_id"/><meta content="ESPN" data-react-helmet="true" property="og:site_name"/><meta content="https://www.espn.com/soccer/team/results/_/id/18966/season" data-react-helmet="true" property="og:url"/><meta content="LAFC Scoring Results" data-react-helmet="true" property="og:title"/><meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" property="og:description"/><meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png" data-react-helmet="true" property="og:image"/><meta content="500" data-react-helmet="true" property="og:image:width"/><meta content="500" data-react-helmet="true" property="og:image:height"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="espn" data-react-helmet="true" name="twitter:site"/><meta content="https://www.espn.com/soccer/team/results/_/id/18966/season" data-react-helmet="true" name="twitter:url"/><meta content="LAFC Results | ESPN" data-react-helmet="true" name="twitter:title"/><meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" name="twitter:description"/><meta content="summary" data-react-helmet="true" name="twitter:card"/><meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png" data-react-helmet="true" name="twitter:image"/><meta content="ESPN" data-react-helmet="true" name="twitter:app:name:iphone"/><meta content="317469184" data-react-helmet="true" name="twitter:app:id:iphone"/><meta content="ESPN" data-react-helmet="true" name="twitter:app:name:googleplay"/><meta content="com.espn.score_center" data-react-helmet="true" name="twitter:app:id:googleplay"/><meta content="LAFC Results | ESPN" data-react-helmet="true" name="title"/><meta content="website" data-react-helmet="true" name="medium"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="en_US" property="og:locale"/>
# <link href="//cdn1.espn.net" rel="preconnect"/>
# <link crossorigin="" href="https://tredir.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
# <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://site.web.api.espn.com" rel="preconnect"/>
# <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
# <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="android-app://com.espn.score_center/sportscenter/x-callback-url/showClubhouse?uid=s:20~l:23§ion=team" rel="alternate"/>
# <link href="ios-app://317469184/sportscenter/x-callback-url/showClubhouse?uid=s:20~l:23§ion=team" rel="alternate"/>
# <link href="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/css/espnfitt.css" rel="stylesheet"/>
# <link data-react-helmet="true" href="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/css/team.results.css" rel="stylesheet"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" rel="canonical"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" hreflang="en-us" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" hreflang="en-us" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.br/futebol/time/resultados/_/id/18966/temporada" hreflang="pt-br" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.br/futebol/time/resultados/_/id/18966/temporada" hreflang="pt-br" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.in/football/team/results/_/id/18966/season" hreflang="en-in" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-es" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-es" rel="alternate"/><link data-react-helmet="true" href="https://africa.espn.com/football/team/results/_/id/18966/season" hreflang="en-za" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ve/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ve" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ve/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cr" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.cl/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cl" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.mx/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-mx" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.co/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-co" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.pe/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-pe" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ar/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ar" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-us" rel="alternate"/><link data-react-helmet="true" href="https://tv5.espn.com/football/team/results/_/id/18966/season" hreflang="en-ph" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.co.uk/football/team/results/_/id/18966/season" hreflang="en-gb" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.sg/football/team/results/_/id/18966/season" hreflang="en-sg" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.gt/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-gt" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.uy/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-uy" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.do/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-do" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ec/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ec" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.pa/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-pa" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.co.cr/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cr" rel="alternate"/>
# <style id="fittLoadingStyle" type="text/css">
#    .page-container,
#    .Nav__Primary__Menu,
#    .Nav__Secondary__Menu,
#     .NavSecondary--GamePackage,
#    .Gamestrip,
#    .Ad:before {
#        opacity:                    0;
#    }
# </style>
# <noscript>
# <style type="text/css">
#                 div.HeaderScoreboardContainer, div.Ad, div.sponsored-content { display: none !important; }
#                 .page-container,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item a,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item .Nav__Primary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Title .Nav__Secondary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Item .Nav__Secondary__Menu__Link {
#                     opacity: 1;
#                 }
#             </style>
# </noscript>
# </head>
# <body>
# <div id="espnfitt"><div id="DataWrapper"><div id="espn-analytics"><div class="bp-mobileMDPlus bp-mobileLGPlus bp-tabletPlus bp-desktopPlus bp-desktopLGPlus" data-fitt-page-type="team"><div data-page-modifier=""><div></div><div><div class="HeaderScoreboardContainer HeaderScoreboardContainer--loading"><section aria-label="HeaderScoreboard" class="HeaderScoreboard HeaderScoreboard--empty"><button class="HiddenSkipNav">Skip to navigation</button><div class="HeaderScoreboard__Wrapper"><div class="HeaderScoreboard__Carousel__Container"><div class="HeaderScoreboard__Carousel"><div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--prev is-disabled"><svg class="icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__caret__left"></use></svg></div><div class="HeaderScoreboard__Carousel__Wrapper"><div style="transform:translateX(0px);transition:0.7s ease"><section class="HeaderScoreboard__Events"><section class="HeaderScoreboard__SportSection"><div class="ScoreCell ScoreCell--md" role="group"><a class="ScoreCell__Link" data-game-link="true"><div class="ScoreCell__Link__Event__Detail"><div class="ScoreCell__CompetitorDetails"><ul class="ScoreCell__Competitors"></ul></div></div></a></div></section></section></div></div><div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--next is-disabled"><svg class="icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__caret__right"></use></svg></div></div></div></div></section></div></div><div class="db Site__Header__Wrapper sticky top-0"><div class="Site__Header db left-0 top-0 sticky w-100 bg-clr-gray-02 Site__Header--espn"><nav class="Nav__Primary center flex justify-between items-center"><div class="Nav__Primary__Branding__Logo"><h1><a class="Nav__Primary__ToggleMenu" href="#"><span>Menu</span></a><a class="AnchorLink Nav__Primary__Branding Nav__Primary__Branding--espn" href="/" tabindex="0">ESPN</a></h1></div><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--left w-100"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nfl/" tabindex="0"><span class="Nav__Text">NFL</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nba/" tabindex="0"><span class="Nav__Text">NBA</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mens-college-basketball/" tabindex="0"><span class="Nav__Text">NCAAM</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative Nav__Primary__Menu__Item--active"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/soccer/" tabindex="0"><span class="Nav__Text">Soccer</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mma/" tabindex="0"><span class="Nav__Text">MMA</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mlb/" tabindex="0"><span class="Nav__Text">MLB</span></a></li><li aria-hidden="true" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com" tabindex="-1"><svg class="Nav__Primary__Icon__MoreSports icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__more__dots"></use></svg></a></li></ul><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--right flex-none"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.c ...
# <script type="text/javascript">window['__espnfitt__']={"app":{"uid":"espnfitt","mode":"universal","apiEnv":"production","envName":"prod","cdnPath":"//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client","webpack":{"chunks":{"404":{"path":"404","hash":"b889a83814fec86b1fbc"},"cross-fitt.admin":{"path":"cross-fitt/admin","hash":"a14f20128e58dafbfac3"},"admin":{"path":"admin","hash":"e719d9522b483eab223d"},"banner":{"path":"banner","hash":"b5678f8af37a9baa2bc2"},"banner.webview":{"path":"banner/webview","hash":"b7ed01254a463bca97b3"},"competitions":{"path":"competitions","hash":"ca09bc51ceb30cab51f3"},"editions":{"path":"editions","hash":"06fde41ea58bf2e17590"},"editions.webview":{"path":"editions/webview","hash":"6f68852d28e66415a2a3"},"fpi":{"path":"fpi","hash":"86ec2bc926d735b92984"},"fpi.webview":{"path":"fpi/webview","hash":"964fa7ffc8480f980be7"},"futures":{"path":"futures","hash":"732d9d73655578a84e6d"},"futures.webview":{"path":"futures/webview","hash":"04de90c827d5cbff7d34"},"gamepackage":{"path":"gamepackage","hash":"c71340d8fd83476072a5"},"gamepackage.basketball":{"path":"gamepackage/basketball","hash":"dc6705330eabc8b749cf"},"gamepackage.basketball.webview":{"path":"gamepackage/basketball/webview","hash":"045f2e2b7f78e80b98ce"},"gamepackage.cricket":{"path":"gamepackage/cricket","hash":"bb3839b9b63aca9b4fc6"},"gamepackage.cricket.cricinfo":{"path":"gamepackage/cricket/cricinfo"},"gamepackage.hockey":{"path":"gamepackage/hockey","hash":"de5e706bbb08f91fca3c"},"gamepackage.hockey.webview":{"path":"gamepackage/hockey/webview","hash":"455ae9159bbcc16a849b"},"gamepackage.mma":{"path":"gamepackage/mma","hash":"117869d18c73a884ac37"},"gamepackage.mma.webview":{"path":"gamepackage/mma/webview","hash":"efc207a9b6402139832e"},"gamepackage.racing":{"path":"gamepackage/racing","hash":"f9b8c2041451b174ff77"},"gamepackage.racing.webview":{"path":"gamepackage/racing/webview","hash":"39be9036fa7b0e2afcf7"},"gamepackage.rugby":{"path":"gamepackage/rugby","hash":"89e7a05584fddf832054"},"history":{"path":"history","hash":"315eefbad83d0e68d1c7"},"history.webview":{"path":"history/webview","hash":"97cce6ca260e8686b874"},"home":{"path":"home","hash":"2fd657891781a4bf6587"},"injuries":{"path":"injuries","hash":"8ddf8f14dc6c5def387c"},"injuries.webview":{"path":"injuries/webview","hash":"46db47f8f9471fea0e7e"},"leaderboard":{"path":"leaderboard","hash":"95b78ba8dede8995384b"},"leaderboard.webview":{"path":"leaderboard/webview","hash":"6c69504384ab8a15feae"},"league":{"path":"league","hash":"ff1b10956206b5495322"},"lines":{"path":"lines","hash":"94cdd0c837ce00e7e35e"},"lines.webview":{"path":"lines/webview","hash":"21349a81a859d8a3843a"},"picks":{"path":"picks","hash":"8eecb218e76aef5fdee5"},"picks.webview":{"path":"picks/webview","hash":"c94394fb98b57ba5b15f"},"player":{"path":"player","hash":"ba520ab46632048b1e03"},"player.baseball":{"path":"player/baseball","hash":"fd3702bff04985715f14"},"player.baseball.webview":{"path":"player/baseball/webview","hash":"a9d40abf5f6142de8773"},"player.basketball":{"path":"player/basketball","hash":"1e329eab535d82688be5"},"player.basketball.webview":{"path":"player/basketball/webview","hash":"09241a94ee837bcaca67"},"player.cricket":{"path":"player/cricket","hash":"ae5f27db8177d2974d48"},"player.cricket.cricinfo":{"path":"player/cricket/cricinfo"},"player.cricket.webview":{"path":"player/cricket/webview","hash":"3183ae6f01dc695b6fb7"},"player.football":{"path":"player/football","hash":"56562e34e05539480ab1"},"player.football.webview":{"path":"player/football/webview","hash":"1a6e60590b16ab2aeb2a"},"player.golf":{"path":"player/golf","hash":"d96bd472e3d2a03c0f69"},"player.golf.webview":{"path":"player/golf/webview","hash":"495da98555168171a3e6"},"player.hockey":{"path":"player/hockey","hash":"90b6eb9898cadb6045ac"},"player.hockey.webview":{"path":"player/hockey/webview","hash":"966b596c0545a159ada2"},"player.mma":{"path":"player/mma","hash":"5fb55c0d5a986d39ccfd"},"player.mma.webview":{"path":"player/ ...
# <script type="text/javascript">__CDN_PATH__="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client";</script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/espnfitt.js" type="text/javascript"></script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/espn-en.js" type="text/javascript"></script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/team.results.js" type="text/javascript"></script>
# </body>
# </html>

# %%
# find the body of the webpage
[type(item) for item in list(lafc_soup.children)]
lafc_body=list(lafc_soup.children)[3]
lafc_body
# Out:
# <html lang="en">
# <head>
# <!-- ESPNFITT | 4d4b5641d13b | 3596 | 1d4236e078642a9e7f7732436b3c1c306ce20400 | Thu, 19 Mar 2020 22:53:16 GMT -->
# <script type="text/javascript">
#         ;(function(){
#             function gc(n){var r=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return r?r[2]:null}function sc(n){document.cookie=n}function smpl(n){var r=n/100;return!!r&&Math.random()<=r}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(100)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));;
#             _nr && window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,j=y.hash,this[u]=x.now()}function o(){M--,y.hash!==j&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,l="cb"+s,p="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),L=t("ee"),S=L.get("tracer");t(16),x.features.spa=!0;var j,M=0;L.on(u,r),L.on(l,r),L.on(d,o),L.on(p,o),L.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(L,"xhr-resolved"),a(L,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=x.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c] ...
#         })();
#     </script>
# <title data-react-helmet="true">LAFC Results | ESPN</title>
# <meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" name="description"/><meta content="LAFC results, LAFC news, LAFC videos, LAFC stats, LAFC standings, live games LAFC" data-react-helmet="true" name="keywords"/><meta content="116656161708917" data-react-helmet="true" property="fb:app_id"/><meta content="ESPN" data-react-helmet="true" property="og:site_name"/><meta content="https://www.espn.com/soccer/team/results/_/id/18966/season" data-react-helmet="true" property="og:url"/><meta content="LAFC Scoring Results" data-react-helmet="true" property="og:title"/><meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" property="og:description"/><meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png" data-react-helmet="true" property="og:image"/><meta content="500" data-react-helmet="true" property="og:image:width"/><meta content="500" data-react-helmet="true" property="og:image:height"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="espn" data-react-helmet="true" name="twitter:site"/><meta content="https://www.espn.com/soccer/team/results/_/id/18966/season" data-react-helmet="true" name="twitter:url"/><meta content="LAFC Results | ESPN" data-react-helmet="true" name="twitter:title"/><meta content="Visit ESPN to view LAFC match results from all competitions, along with a season-by-season archive." data-react-helmet="true" name="twitter:description"/><meta content="summary" data-react-helmet="true" name="twitter:card"/><meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/18966.png" data-react-helmet="true" name="twitter:image"/><meta content="ESPN" data-react-helmet="true" name="twitter:app:name:iphone"/><meta content="317469184" data-react-helmet="true" name="twitter:app:id:iphone"/><meta content="ESPN" data-react-helmet="true" name="twitter:app:name:googleplay"/><meta content="com.espn.score_center" data-react-helmet="true" name="twitter:app:id:googleplay"/><meta content="LAFC Results | ESPN" data-react-helmet="true" name="title"/><meta content="website" data-react-helmet="true" name="medium"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="en_US" property="og:locale"/>
# <link href="//cdn1.espn.net" rel="preconnect"/>
# <link crossorigin="" href="https://tredir.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
# <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.espn.com" rel="preconnect"/>
# <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
# <link crossorigin="" href="https://site.web.api.espn.com" rel="preconnect"/>
# <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
# <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="android-app://com.espn.score_center/sportscenter/x-callback-url/showClubhouse?uid=s:20~l:23§ion=team" rel="alternate"/>
# <link href="ios-app://317469184/sportscenter/x-callback-url/showClubhouse?uid=s:20~l:23§ion=team" rel="alternate"/>
# <link href="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/css/espnfitt.css" rel="stylesheet"/>
# <link data-react-helmet="true" href="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/css/team.results.css" rel="stylesheet"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" rel="canonical"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" hreflang="en-us" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com/soccer/team/results/_/id/18966/season" hreflang="en-us" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.br/futebol/time/resultados/_/id/18966/temporada" hreflang="pt-br" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.br/futebol/time/resultados/_/id/18966/temporada" hreflang="pt-br" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.in/football/team/results/_/id/18966/season" hreflang="en-in" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-es" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-es" rel="alternate"/><link data-react-helmet="true" href="https://africa.espn.com/football/team/results/_/id/18966/season" hreflang="en-za" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ve/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ve" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ve/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cr" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.cl/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cl" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.mx/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-mx" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.co/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-co" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.pe/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-pe" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ar/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ar" rel="alternate"/><link data-react-helmet="true" href="https://espndeportes.espn.com/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-us" rel="alternate"/><link data-react-helmet="true" href="https://tv5.espn.com/football/team/results/_/id/18966/season" hreflang="en-ph" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.co.uk/football/team/results/_/id/18966/season" hreflang="en-gb" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.sg/football/team/results/_/id/18966/season" hreflang="en-sg" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.gt/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-gt" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.uy/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-uy" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.do/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-do" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.ec/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-ec" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.com.pa/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-pa" rel="alternate"/><link data-react-helmet="true" href="https://www.espn.co.cr/futbol/equipo/resultados/_/id/18966/temporada" hreflang="es-cr" rel="alternate"/>
# <style id="fittLoadingStyle" type="text/css">
#    .page-container,
#    .Nav__Primary__Menu,
#    .Nav__Secondary__Menu,
#     .NavSecondary--GamePackage,
#    .Gamestrip,
#    .Ad:before {
#        opacity:                    0;
#    }
# </style>
# <noscript>
# <style type="text/css">
#                 div.HeaderScoreboardContainer, div.Ad, div.sponsored-content { display: none !important; }
#                 .page-container,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item a,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item .Nav__Primary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Title .Nav__Secondary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Item .Nav__Secondary__Menu__Link {
#                     opacity: 1;
#                 }
#             </style>
# </noscript>
# </head>
# <body>
# <div id="espnfitt"><div id="DataWrapper"><div id="espn-analytics"><div class="bp-mobileMDPlus bp-mobileLGPlus bp-tabletPlus bp-desktopPlus bp-desktopLGPlus" data-fitt-page-type="team"><div data-page-modifier=""><div></div><div><div class="HeaderScoreboardContainer HeaderScoreboardContainer--loading"><section aria-label="HeaderScoreboard" class="HeaderScoreboard HeaderScoreboard--empty"><button class="HiddenSkipNav">Skip to navigation</button><div class="HeaderScoreboard__Wrapper"><div class="HeaderScoreboard__Carousel__Container"><div class="HeaderScoreboard__Carousel"><div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--prev is-disabled"><svg class="icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__caret__left"></use></svg></div><div class="HeaderScoreboard__Carousel__Wrapper"><div style="transform:translateX(0px);transition:0.7s ease"><section class="HeaderScoreboard__Events"><section class="HeaderScoreboard__SportSection"><div class="ScoreCell ScoreCell--md" role="group"><a class="ScoreCell__Link" data-game-link="true"><div class="ScoreCell__Link__Event__Detail"><div class="ScoreCell__CompetitorDetails"><ul class="ScoreCell__Competitors"></ul></div></div></a></div></section></section></div></div><div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--next is-disabled"><svg class="icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__caret__right"></use></svg></div></div></div></div></section></div></div><div class="db Site__Header__Wrapper sticky top-0"><div class="Site__Header db left-0 top-0 sticky w-100 bg-clr-gray-02 Site__Header--espn"><nav class="Nav__Primary center flex justify-between items-center"><div class="Nav__Primary__Branding__Logo"><h1><a class="Nav__Primary__ToggleMenu" href="#"><span>Menu</span></a><a class="AnchorLink Nav__Primary__Branding Nav__Primary__Branding--espn" href="/" tabindex="0">ESPN</a></h1></div><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--left w-100"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nfl/" tabindex="0"><span class="Nav__Text">NFL</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nba/" tabindex="0"><span class="Nav__Text">NBA</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mens-college-basketball/" tabindex="0"><span class="Nav__Text">NCAAM</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative Nav__Primary__Menu__Item--active"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/soccer/" tabindex="0"><span class="Nav__Text">Soccer</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mma/" tabindex="0"><span class="Nav__Text">MMA</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mlb/" tabindex="0"><span class="Nav__Text">MLB</span></a></li><li aria-hidden="true" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com" tabindex="-1"><svg class="Nav__Primary__Icon__MoreSports icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__more__dots"></use></svg></a></li></ul><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--right flex-none"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.c ...
# <script type="text/javascript">window['__espnfitt__']={"app":{"uid":"espnfitt","mode":"universal","apiEnv":"production","envName":"prod","cdnPath":"//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client","webpack":{"chunks":{"404":{"path":"404","hash":"b889a83814fec86b1fbc"},"cross-fitt.admin":{"path":"cross-fitt/admin","hash":"a14f20128e58dafbfac3"},"admin":{"path":"admin","hash":"e719d9522b483eab223d"},"banner":{"path":"banner","hash":"b5678f8af37a9baa2bc2"},"banner.webview":{"path":"banner/webview","hash":"b7ed01254a463bca97b3"},"competitions":{"path":"competitions","hash":"ca09bc51ceb30cab51f3"},"editions":{"path":"editions","hash":"06fde41ea58bf2e17590"},"editions.webview":{"path":"editions/webview","hash":"6f68852d28e66415a2a3"},"fpi":{"path":"fpi","hash":"86ec2bc926d735b92984"},"fpi.webview":{"path":"fpi/webview","hash":"964fa7ffc8480f980be7"},"futures":{"path":"futures","hash":"732d9d73655578a84e6d"},"futures.webview":{"path":"futures/webview","hash":"04de90c827d5cbff7d34"},"gamepackage":{"path":"gamepackage","hash":"c71340d8fd83476072a5"},"gamepackage.basketball":{"path":"gamepackage/basketball","hash":"dc6705330eabc8b749cf"},"gamepackage.basketball.webview":{"path":"gamepackage/basketball/webview","hash":"045f2e2b7f78e80b98ce"},"gamepackage.cricket":{"path":"gamepackage/cricket","hash":"bb3839b9b63aca9b4fc6"},"gamepackage.cricket.cricinfo":{"path":"gamepackage/cricket/cricinfo"},"gamepackage.hockey":{"path":"gamepackage/hockey","hash":"de5e706bbb08f91fca3c"},"gamepackage.hockey.webview":{"path":"gamepackage/hockey/webview","hash":"455ae9159bbcc16a849b"},"gamepackage.mma":{"path":"gamepackage/mma","hash":"117869d18c73a884ac37"},"gamepackage.mma.webview":{"path":"gamepackage/mma/webview","hash":"efc207a9b6402139832e"},"gamepackage.racing":{"path":"gamepackage/racing","hash":"f9b8c2041451b174ff77"},"gamepackage.racing.webview":{"path":"gamepackage/racing/webview","hash":"39be9036fa7b0e2afcf7"},"gamepackage.rugby":{"path":"gamepackage/rugby","hash":"89e7a05584fddf832054"},"history":{"path":"history","hash":"315eefbad83d0e68d1c7"},"history.webview":{"path":"history/webview","hash":"97cce6ca260e8686b874"},"home":{"path":"home","hash":"2fd657891781a4bf6587"},"injuries":{"path":"injuries","hash":"8ddf8f14dc6c5def387c"},"injuries.webview":{"path":"injuries/webview","hash":"46db47f8f9471fea0e7e"},"leaderboard":{"path":"leaderboard","hash":"95b78ba8dede8995384b"},"leaderboard.webview":{"path":"leaderboard/webview","hash":"6c69504384ab8a15feae"},"league":{"path":"league","hash":"ff1b10956206b5495322"},"lines":{"path":"lines","hash":"94cdd0c837ce00e7e35e"},"lines.webview":{"path":"lines/webview","hash":"21349a81a859d8a3843a"},"picks":{"path":"picks","hash":"8eecb218e76aef5fdee5"},"picks.webview":{"path":"picks/webview","hash":"c94394fb98b57ba5b15f"},"player":{"path":"player","hash":"ba520ab46632048b1e03"},"player.baseball":{"path":"player/baseball","hash":"fd3702bff04985715f14"},"player.baseball.webview":{"path":"player/baseball/webview","hash":"a9d40abf5f6142de8773"},"player.basketball":{"path":"player/basketball","hash":"1e329eab535d82688be5"},"player.basketball.webview":{"path":"player/basketball/webview","hash":"09241a94ee837bcaca67"},"player.cricket":{"path":"player/cricket","hash":"ae5f27db8177d2974d48"},"player.cricket.cricinfo":{"path":"player/cricket/cricinfo"},"player.cricket.webview":{"path":"player/cricket/webview","hash":"3183ae6f01dc695b6fb7"},"player.football":{"path":"player/football","hash":"56562e34e05539480ab1"},"player.football.webview":{"path":"player/football/webview","hash":"1a6e60590b16ab2aeb2a"},"player.golf":{"path":"player/golf","hash":"d96bd472e3d2a03c0f69"},"player.golf.webview":{"path":"player/golf/webview","hash":"495da98555168171a3e6"},"player.hockey":{"path":"player/hockey","hash":"90b6eb9898cadb6045ac"},"player.hockey.webview":{"path":"player/hockey/webview","hash":"966b596c0545a159ada2"},"player.mma":{"path":"player/mma","hash":"5fb55c0d5a986d39ccfd"},"player.mma.webview":{"path":"player/ ...
# <script type="text/javascript">__CDN_PATH__="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client";</script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/espnfitt.js" type="text/javascript"></script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/espn-en.js" type="text/javascript"></script><script src="//cdn1.espn.net/fitt/1d4236e07864-release-03-18-2020.1/client/team.results.js" type="text/javascript"></script>
# </body>
# </html>

# %%
#Find all the games in the body
lafc_games=lafc_body.findAll("tr",{"class":"Table__TR Table__TR--sm Table__even"})

print("Number of Games for LAFC:",len(lafc_games))
print("")
print("Output for one game")
print("-----")
print(lafc_games[0])
# Out:
# Number of Games for LAFC: 89
#
# Output for one game
# -----
# <tr class="Table__TR Table__TR--sm Table__even" data-idx="0"><td class="Table__TD"><div class="matchTeams">Sun, Mar 8</div></td><td class="Table__TD"><div class="local flex items-center"><a class="AnchorLink Table__Team" href="/soccer/team/_/id/18966/lafc" tabindex="0">LAFC</a></div></td><td class="Table__TD"><span class="Table__Team score"><a class="AnchorLink" href="/soccer/team/_/id/18966/lafc" tabindex="0"><figure class="Image aspect-ratio--parent Logo Logo__sm"><div class="Image__Wrapper aspect-ratio--1x1"><img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/></div></figure></a><a class="AnchorLink" href="/soccer/match/_/gameId/561813" tabindex="0">3 - 3</a><a class="AnchorLink" href="/soccer/team/_/id/10739/philadelphia-union" tabindex="0"><figure class="Image aspect-ratio--parent Logo Logo__sm"><div class="Image__Wrapper aspect-ratio--1x1"><img alt="" class="aspect-ratio--child" data-mptype="image" src="..." title=""/></div></figure></a></span></td><td class="Table__TD"><div class="away flex items-center"><a class="AnchorLink Table__Team" href="/soccer/team/_/id/10739/philadelphia-union" tabindex="0">Philadelphia Union</a></div></td><td class="Table__TD"><span><a class="AnchorLink" href="/soccer/match/_/gameId/561813" tabindex="0">FT</a></span></td><td class="Table__TD"><span>Major League Soccer</span></td></tr>

# %% [markdown]
# <b><i>Looking at the output of the individual game, it seems as if there are multiple links and classes that contain AnchorLink. What I have decided to do is find all the links in the body that have the text of FT or FT-Pens. From here I can extract the game ID..</b> </i>

# %%
#findall links where text is FT or FT-Pens
links=lafc_body.findAll("a",{"class":"AnchorLink"},text=("FT","FT-Pens"))
print("Number of links:",len(links))
print("")
print("Output for one link")
print("-----")
print(links[0])
# Out:
# Number of links: 89
#
# Output for one link
# -----
# <a class="AnchorLink" href="/soccer/match/_/gameId/561813" tabindex="0">FT</a>

# %%
#find game_id's

lafc_game_ids=[]
for link in links:
    #append the id list with the last 6 numbers of the link
    lafc_game_ids.append(link["href"][-6:])
print("Number of games:",len(lafc_game_ids))
print("")
print("Output for game")
print("-----")
print(lafc_game_ids[0])
print("")
#Does the number of games = links = game_ids?
print("We collected all of the game_IDs:",len(lafc_games)==len(links)==len(lafc_game_ids))
# Out:
# Number of games: 89
#
# Output for game
# -----
# 561813
#
# We collected all of the game_IDs: True
